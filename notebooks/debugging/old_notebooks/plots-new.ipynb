# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_y5 = pd.read_csv('../models/run2/skip-torch-4D-y5-99bdcf9b--16-48-leaky_relu-512-adam-exp-schedule-mse-val_mse-96.769905-99.684618/test-results-99bdcf9b-96.769905-99.684618.csv')

# %%
df_y5.describe()
# Out:
#           Unnamed: 0            x1             x2             x3  \
# count  499712.000000  4.997120e+05  499712.000000  499712.000000
# mean   249855.500000  1.321381e-01       0.499469       0.499598
# std    144254.573196  2.209283e-01       0.288691       0.288807
# min         0.000000  6.066240e-10       0.000004       0.000001
# 25%    124927.750000  3.040374e-03       0.249476       0.249090
# 50%    249855.500000  2.281552e-02       0.499650       0.499897
# 75%    374783.250000  1.511605e-01       0.749424       0.749368
# max    499711.000000  9.999568e-01       0.999998       0.999999
#
#                  x4      y5_scaled             y5  y5_scaled_pred  \
# count  4.997120e+05  499712.000000  499712.000000   499712.000000
# mean   4.991992e-01      -0.754574     -16.256098       -0.756282
# std    2.883081e-01       3.558973     247.092445        3.556280
# min    1.887156e-09     -10.787503  -48411.017079       -9.070869
# ...

# %%
plt.hist(df_y5[abs(df_y5.delta_real) < 10].delta_real, bins=100, histtype='step', label='h2')
#plt.hist(df_y13[abs(df_y13.delta_real) < 10].delta_real, bins=100, histtype='step', label='h4')
plt.grid('dotted', alpha=0.5)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_12528/1003256140.py in ?()
# ----> 1 plt.hist(df_y5[abs(df_y5.delta_real) < 10].delta_real, bins=100, histtype='step', label='h2')
#       2 #plt.hist(df_y13[abs(df_y13.delta_real) < 10].delta_real, bins=100, histtype='step', label='h4')
#       3 plt.grid('dotted', alpha=0.5)
#       4 plt.legend()
#
# ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'delta_real'

# %%
df_y5 = pd.read_csv('../model/skip-torch-4D-y5_y6-cec13ce3-MC-16-32-swish-512-adam-exp-schedule-mse-val_mse-99.601906-99.998775/test-results-cec13ce3-99.601906-99.998775.csv')
df_y13 = pd.read_csv('../model/skip-torch-4D-y13_y14-7a9ab320-MC-16-32-swish-512-adam-exp-schedule-mse-val_mse-99.472801-99.980943/test-results-7a9ab320-99.472801-99.980943.csv')

# %%
plt.hist(df_y5[abs(df_y5.delta_y5) < 5].delta_y5, bins=100, histtype='step', label='h2', density=True)
plt.grid('dotted', alpha=0.5)
plt.xlabel(r'$\delta$')
plt.ylabel(r'pdf')
plt.legend()
plt.show()

# %%
plt.hist(df_y5[abs(df_y5.scaled_delta_y5) < 5].scaled_delta_y5, bins=100, histtype='step', label='h2', density=True)
plt.grid('dotted', alpha=0.5)
plt.xlabel(r'$\delta$')
plt.ylabel(r'pdf')
plt.legend()
plt.show()

# %%
df_y13
# Out:
#         Unnamed: 0        x1        x2        x3        x4    y_test  \
# 0                0  0.000007  0.771066  0.436337  0.521262  3.388456
# 1                1  0.000009  0.581542  0.511984  0.521890 -4.811494
# 2                2  0.000012  0.463915  0.528051  0.508386 -5.123053
# 3                3  0.000013  0.961049  0.543344  0.505631  5.526618
# 4                4  0.000015  0.361104  0.520037  0.524839 -5.169849
# ...            ...       ...       ...       ...       ...       ...
# 499995      499995  0.029593  0.658663  0.373572  0.426698  3.664798
# 499996      499996  0.029598  0.042156  0.526656  0.529691 -3.547845
# 499997      499997  0.029602  0.922126  0.448913  0.499104  5.096587
# 499998      499998  0.029602  0.430710  0.517777  0.483601  3.244319
# 499999      499999  0.029626  0.989237  0.520993  0.518114  5.184889
#
#         y_test_real    y_pred  y_pred_real     delta  delta_real
# 0         28.620174  3.312975    26.466720 -2.227581   -7.524253
# ...

# %%
df_y5
# Out:
#         Unnamed: 0        x1        x2        x3        x4    y_test  \
# 0                0  0.000007  0.771066  0.436337  0.521262  5.032712
# 1                1  0.000009  0.581542  0.511984  0.521890  5.164520
# 2                2  0.000012  0.463915  0.528051  0.508386  4.962266
# 3                3  0.000013  0.961049  0.543344  0.505631  3.579522
# 4                4  0.000015  0.361104  0.520037  0.524839  4.504727
# ...            ...       ...       ...       ...       ...       ...
# 499995      499995  0.029593  0.658663  0.373572  0.426698 -3.147965
# 499996      499996  0.029598  0.042156  0.526656  0.529691 -5.475602
# 499997      499997  0.029602  0.922126  0.448913  0.499104  0.845050
# 499998      499998  0.029602  0.430710  0.517777  0.483601 -3.457574
# 499999      499999  0.029626  0.989237  0.520993  0.518114  4.959708
#
#         y_test_real    y_pred  y_pred_real     delta  delta_real
# 0        152.348295  5.028186   151.655789 -0.089934   -0.454554
# ...

# %%
df_y13 = pd.read_csv('../models/skip-torch-4D-y13-cef19dbd--16-32-leaky_relu-512-adam-exp-schedule-mse-val_mse-96.855666-99.594712/test-results-cef19dbd-96.855666-99.594712.csv')

# %%
df_y13.describe()
# Out:
#           Unnamed: 0            x1             x2             x3  \
# count  499712.000000  4.997120e+05  499712.000000  499712.000000
# mean   249855.500000  1.321381e-01       0.499469       0.499598
# std    144254.573196  2.209283e-01       0.288691       0.288807
# min         0.000000  6.066240e-10       0.000004       0.000001
# 25%    124927.750000  3.040374e-03       0.249476       0.249090
# 50%    249855.500000  2.281552e-02       0.499650       0.499897
# 75%    374783.250000  1.511605e-01       0.749424       0.749368
# max    499711.000000  9.999568e-01       0.999998       0.999999
#
#                  x4     y13_scaled            y13  y13_scaled_pred  \
# count  4.997120e+05  499712.000000  499712.000000    499712.000000
# mean   4.991992e-01       0.746371      15.668259         0.735708
# std    2.883081e-01       3.558288     339.197844         3.549626
# min    1.887156e-09     -11.726637 -123825.551386        -5.885531
# ...

# %%
plt.hist(df_y13[abs(df_y13.delta_real) < 10].delta_real, bins=100, histtype='step', label='h2')
#plt.hist(df_y13[abs(df_y13.delta_real) < 10].delta_real, bins=100, histtype='step', label='h4')
plt.grid('dotted', alpha=0.5)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1584/1299817201.py in ?()
# ----> 1 plt.hist(df_y13[abs(df_y13.delta_real) < 10].delta_real, bins=100, histtype='step', label='h2')
#       2 #plt.hist(df_y13[abs(df_y13.delta_real) < 10].delta_real, bins=100, histtype='step', label='h4')
#       3 plt.grid('dotted', alpha=0.5)
#       4 plt.legend()
#
# ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'delta_real'

# %%
df_y5 = pd.read_csv('../model/skip-torch-4D-y5_y6-cec13ce3-MC-16-32-swish-512-adam-exp-schedule-mse-val_mse-99.601906-99.998775/test-results-cec13ce3-99.601906-99.998775.csv')
df_y13 = pd.read_csv('../model/skip-torch-4D-y13_y14-7a9ab320-MC-16-32-swish-512-adam-exp-schedule-mse-val_mse-99.472801-99.980943/test-results-7a9ab320-99.472801-99.980943.csv')

# %%
plt.hist(df_y13[abs(df_y13.delta_y13) < 5].delta_y13, bins=100, histtype='step', label='h4', density=True)
plt.grid('dotted', alpha=0.5)
plt.xlabel(r'$\delta$')
plt.ylabel(r'pdf')
plt.legend()
plt.show()

# %%
plt.hist(df_y13[abs(df_y13.scaled_delta_y13) < 5].scaled_delta_y13, bins=100, histtype='step', label='h4', density=True)
plt.grid('dotted', alpha=0.5)
plt.xlabel(r'$\delta$')
plt.ylabel(r'pdf')
plt.legend()
plt.show()

# %%
df_y13
# Out:
#         Unnamed: 0        x1        x2        x3        x4    y_test  \
# 0                0  0.000007  0.771066  0.436337  0.521262  3.388456
# 1                1  0.000009  0.581542  0.511984  0.521890 -4.811494
# 2                2  0.000012  0.463915  0.528051  0.508386 -5.123053
# 3                3  0.000013  0.961049  0.543344  0.505631  5.526618
# 4                4  0.000015  0.361104  0.520037  0.524839 -5.169849
# ...            ...       ...       ...       ...       ...       ...
# 499995      499995  0.029593  0.658663  0.373572  0.426698  3.664798
# 499996      499996  0.029598  0.042156  0.526656  0.529691 -3.547845
# 499997      499997  0.029602  0.922126  0.448913  0.499104  5.096587
# 499998      499998  0.029602  0.430710  0.517777  0.483601  3.244319
# 499999      499999  0.029626  0.989237  0.520993  0.518114  5.184889
#
#         y_test_real    y_pred  y_pred_real     delta  delta_real
# 0         28.620174  3.312975    26.466720 -2.227581   -7.524253
# ...

# %%
df_y5
# Out:
#         Unnamed: 0        x1        x2        x3        x4    y_test  \
# 0                0  0.000007  0.771066  0.436337  0.521262  5.032712
# 1                1  0.000009  0.581542  0.511984  0.521890  5.164520
# 2                2  0.000012  0.463915  0.528051  0.508386  4.962266
# 3                3  0.000013  0.961049  0.543344  0.505631  3.579522
# 4                4  0.000015  0.361104  0.520037  0.524839  4.504727
# ...            ...       ...       ...       ...       ...       ...
# 499995      499995  0.029593  0.658663  0.373572  0.426698 -3.147965
# 499996      499996  0.029598  0.042156  0.526656  0.529691 -5.475602
# 499997      499997  0.029602  0.922126  0.448913  0.499104  0.845050
# 499998      499998  0.029602  0.430710  0.517777  0.483601 -3.457574
# 499999      499999  0.029626  0.989237  0.520993  0.518114  4.959708
#
#         y_test_real    y_pred  y_pred_real     delta  delta_real
# 0        152.348295  5.028186   151.655789 -0.089934   -0.454554
# ...

# %%
df_y18 = pd.read_csv('../models/skip-torch-4D-y18-f17c5b7d--16-32-leaky_relu-512-adam-exp-schedule-mse-val_mse--56.608695-99.972566/test-results-f17c5b7d--56.608695-99.972566.csv')

# %%
df_y18.describe()
# Out:
#           Unnamed: 0            x1             x2             x3  \
# count  499712.000000  4.997120e+05  499712.000000  499712.000000
# mean   249855.500000  1.321381e-01       0.499469       0.499598
# std    144254.573196  2.209283e-01       0.288691       0.288807
# min         0.000000  6.066240e-10       0.000004       0.000001
# 25%    124927.750000  3.040374e-03       0.249476       0.249090
# 50%    249855.500000  2.281552e-02       0.499650       0.499897
# 75%    374783.250000  1.511605e-01       0.749424       0.749368
# max    499711.000000  9.999568e-01       0.999998       0.999999
#
#                  x4     y18_scaled            y18  y18_scaled_pred  \
# count  4.997120e+05  499712.000000  499712.000000    499712.000000
# mean   4.991992e-01      -0.000284      -0.098730        -0.000724
# std    2.883081e-01       3.456578     116.538979         3.455562
# min    1.887156e-09      -7.905556   -2711.309960        -6.565498
# ...

# %%
plt.hist(df_y18[abs(df_y18.delta_real) < 10].delta_real, bins=100, histtype='step', label='h2')
#plt.hist(df_y13[abs(df_y13.delta_real) < 10].delta_real, bins=100, histtype='step', label='h4')
plt.grid('dotted', alpha=0.5)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3110/3707631623.py in ?()
# ----> 1 plt.hist(df_y18[abs(df_y18.delta_real) < 10].delta_real, bins=100, histtype='step', label='h2')
#       2 #plt.hist(df_y13[abs(df_y13.delta_real) < 10].delta_real, bins=100, histtype='step', label='h4')
#       3 plt.grid('dotted', alpha=0.5)
#       4 plt.legend()
#
# ~/.conda/envs/myenv/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'delta_real'

# %%
df_y5 = pd.read_csv('../model/skip-torch-4D-y5_y6-cec13ce3-MC-16-32-swish-512-adam-exp-schedule-mse-val_mse-99.601906-99.998775/test-results-cec13ce3-99.601906-99.998775.csv')
df_y13 = pd.read_csv('../model/skip-torch-4D-y13_y14-7a9ab320-MC-16-32-swish-512-adam-exp-schedule-mse-val_mse-99.472801-99.980943/test-results-7a9ab320-99.472801-99.980943.csv')

# %%
plt.hist(df_y18[abs(df_y18.delta_y18) < 5].delta_y18, bins=100, histtype='step', label='h4', density=True)
plt.grid('dotted', alpha=0.5)
plt.xlabel(r'$\delta$')
plt.ylabel(r'pdf')
plt.legend()
plt.show()

# %%
plt.hist(df_y18[abs(df_y18.scaled_delta_y18) < 5].scaled_delta_y18, bins=100, histtype='step', label='h4', density=True)
plt.grid('dotted', alpha=0.5)
plt.xlabel(r'$\delta$')
plt.ylabel(r'pdf')
plt.legend()
plt.show()
